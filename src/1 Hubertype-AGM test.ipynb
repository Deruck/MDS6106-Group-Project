# %% [markdown]
# ## 生成数据

# %%
from tools.datasets import DataGenerator
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
# %matplotlib inline


data_generator = DataGenerator(p=3, sep=10, seed=10)
data, label = data_generator.get_data()

from tools.full_model import MyCluster

my_cluster=MyCluster(data=data,
                     model='Huber-type',
                     minimizer='AGM',
                     lambda_=0.2,
                     tol=0.005,
                     delta=0.006)



my_cluster.optimize()

my_cluster.solution_to_cluster(epsilon=0.01)
my_cluster.get_result_panel(label,beta=1)
my_cluster.plot2d(data_generator)
# Out:
# Applying: AGM
# iter:2419	d_norm:0.0044	obj:602.96638
# Complete!
# --------
# Result
# --------
# + Model: Huber-type
#   - lambda:                    0.2
#   - delta:                   0.006
# + Minimizer: AGM
#   - Max Iteration:             inf
#   - Tolerance:               0.005
# + Performance:
#   - Data Shape:             2 x 60
#   - Iteration Times:          2419
#   - Duration:               5.883s
#   - Number of Clusters:          3
#   - Number of Classes:           3
#   - Compression Ratio:       0.133
#   - Homogeneity:             1.000
#   - Completeness:            1.000
#   - V-measure(beta=1):       1.000

# %%
from tools.datasets import DataGenerator
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
# %matplotlib inline


data_generator = DataGenerator(p=3, sep=10, seed=1)
data, label = data_generator.get_data()

from tools.full_model import MyCluster

my_cluster=MyCluster(data=data,
                     model='Huber-type',
                     minimizer='AGM',
                     lambda_=0.15,
                     tol=0.005,
                     delta=0.005)



my_cluster.optimize()

my_cluster.solution_to_cluster(epsilon=0.01)
my_cluster.get_result_panel(label,beta=1)
my_cluster.plot2d(data_generator)
# Out:
# Applying: AGM
# iter:2028	d_norm:0.0045	obj:364.8878
# Complete!
# --------
# Result
# --------
# + Model: Huber-type
#   - lambda:                   0.15
#   - delta:                   0.005
# + Minimizer: AGM
#   - Max Iteration:             inf
#   - Tolerance:               0.005
# + Performance:
#   - Data Shape:             2 x 60
#   - Iteration Times:          2028
#   - Duration:               5.421s
#   - Number of Clusters:          3
#   - Number of Classes:           3
#   - Compression Ratio:       0.184
#   - Homogeneity:             1.000
#   - Completeness:            1.000
#   - V-measure(beta=1):       1.000

# %%
from tools.datasets import DataGenerator
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
# %matplotlib inline


data_generator = DataGenerator(p=4, sep=10, seed=2)
data, label = data_generator.get_data()

from tools.full_model import MyCluster

my_cluster=MyCluster(data=data,
                     model='Huber-type',
                     minimizer='AGM',
                     lambda_=0.1,
                     tol=0.005,
                     delta=0.005)



my_cluster.optimize()

my_cluster.solution_to_cluster(epsilon=0.01)
my_cluster.get_result_panel(label,beta=1)
my_cluster.plot2d(data_generator)
# Out:
# Applying: AGM
# iter:1530	d_norm:0.0046	obj:306.7461
# Complete!
# --------
# Result
# --------
# + Model: Huber-type
#   - lambda:                    0.1
#   - delta:                   0.005
# + Minimizer: AGM
#   - Max Iteration:             inf
#   - Tolerance:               0.005
# + Performance:
#   - Data Shape:             2 x 80
#   - Iteration Times:          1530
#   - Duration:               4.503s
#   - Number of Clusters:          4
#   - Number of Classes:           4
#   - Compression Ratio:       0.097
#   - Homogeneity:             0.750
#   - Completeness:            0.954
#   - V-measure(beta=1):       0.840

# %% [markdown]
# ## 真实数据

# %% [markdown]
# ### wine

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
# %matplotlib inline


from tools.full_model import MyCluster
from tools.datasets import load_data
data,label=load_data('wine')

my_cluster=MyCluster(data=data,
                     model='Huber-type',
                     minimizer='AGM',
                     lambda_=0.0245,
                     tol=0.005,
                     delta=0.0045)



my_cluster.optimize()
my_cluster.solution_to_cluster(epsilon=0.01)
my_cluster.get_result_panel(label,beta=1)
# Out:
# Applying: AGM
# iter:991	d_norm:0.0050	obj:195.32895
# Complete!
# --------
# Result
# --------
# + Model: Huber-type
#   - lambda:                 0.0245
#   - delta:                  0.0045
# + Minimizer: AGM
#   - Max Iteration:             inf
#   - Tolerance:               0.005
# + Performance:
#   - Data Shape:           13 x 178
#   - Iteration Times:           991
#   - Duration:              11.584s
#   - Number of Clusters:         34
#   - Number of Classes:           3
#   - Compression Ratio:       0.013
#   - Homogeneity:             0.553
#   - Completeness:            0.381
#   - V-measure(beta=1):       0.451

# %% [markdown]
# ### vowel

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
# %matplotlib inline


from tools.full_model import MyCluster
from tools.datasets import load_data
data,label=load_data('vowel')

my_cluster=MyCluster(data=data,
                     model='Huber-type',
                     minimizer='AGM',
                     lambda_=0.00685,
                     tol=0.005,
                     delta=0.005)



my_cluster.optimize()
my_cluster.solution_to_cluster(epsilon=0.01)
my_cluster.get_result_panel(label,beta=1)
# Out:
# Applying: AGM
# iter:1329	d_norm:0.0048	obj:426.5934
# Complete!
# --------
# Result
# --------
# + Model: Huber-type
#   - lambda:                0.00685
#   - delta:                   0.005
# + Minimizer: AGM
#   - Max Iteration:             inf
#   - Tolerance:               0.005
# + Performance:
#   - Data Shape:           10 x 528
#   - Iteration Times:          1329
#   - Duration:              73.966s
#   - Number of Clusters:         93
#   - Number of Classes:          11
#   - Compression Ratio:       0.028
#   - Homogeneity:             0.544
#   - Completeness:            0.469
#   - V-measure(beta=1):       0.504
